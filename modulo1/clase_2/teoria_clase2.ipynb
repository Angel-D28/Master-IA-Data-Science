# %% [markdown]
# Tipos de variables y Datos

# %%
#---Comentario
nombre = "Angel David Diaz Pinilla"
edad = 45
correo = "Angeldaviddiazpinilla@gmail.com"
activo = True
promedio = 8.7

#---Imprimir los datos del estudiante
print(f"Estudiante: {nombre}")
print(f"Estudiante: {edad} -> tipo: {type(edad)}")
print(f"Estudiante: {correo}")
print(f"Estudiante: {promedio}")
# Out:
# Estudiante: Angel David Diaz Pinilla
# Estudiante: 45 -> tipo: <class 'int'>
# Estudiante: Angeldaviddiazpinilla@gmail.com
# Estudiante: 8.7

# %% [markdown]
# Ingreso de Datos

# %%
nombre = input("Ingrese el nombre del estudiante: ")
edad = int(input("Ingrese la edad del estudiante: "))
print(f"Estudiante Registrado Exitosamente\nNombre: {nombre}\nEdad: {edad} años.")
# Out:
# Estudiante Registrado Exitosamente
# Nombre: ANGEL
# Edad: 19 años.
